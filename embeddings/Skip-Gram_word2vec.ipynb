# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import random

threshold_parameter = 1e-5
frequency_of_word = np.zeros(np.max(int_words)+1)
for i in range(len(int_words)):
    frequency_of_word[int_words[i]] += 1

frequency_of_word = frequency_of_word / len(int_words)
p_w = 1 - np.sqrt(threshold_parameter/frequency_of_word)
train_words = [word for word in int_words if random.random() < (1 - p_w[word])] # The final subsampled word list
len(train_words)
# Out:
# 4626228

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = "inputs")
    labels = tf.placeholder(tf.int32, [None, None], name = "labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200  # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding), stddev = 0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6452 0.2030 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5916 0.2023 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4963 0.2032 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6171 0.2009 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5004 0.2023 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5633 0.2024 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5375 0.2020 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5356 0.2018 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4712 0.2018 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3989 0.2005 sec/batch
# Nearest to been: melodic, encouraged, leges, sundarbans, stub, palm, unbiased, phys,
# Nearest to about: wwii, kimmel, misdemeanors, shave, nv, insertafter, catarina, assassinated,
# Nearest to at: consolidation, delilah, consults, cliath, frying, lastly, neo, brine,
# Nearest to state: naturalized, spamalot, slashes, anthropoid, coaling, motown, confessing, soir,
# Nearest to but: tenth, antwerp, displaced, plancherel, realises, sassanian, phenol, intrusion,
# Nearest to used: emotive, museum, tables, rallies, innovators, fer, mamre, photons,
# Nearest to so: waveforms, regressive, regulating, minting, mousetrap, frey, worcestershire, historia,
# Nearest to a: alongside, hickok, bookseller, alphonso, mircea, chromosomes, exemplifies, hikari,
# Nearest to articles: thrusts, streamlined, condoms, hoover, mate, proffered, rigdon, src,
# Nearest to channel: lane, representational, thalberg, flagella, nair, nameless, lightly, geological,
# Nearest to running: unlock, replicant, suggestive, wilber, discussing, bunyips, minnesotans, confidant,
# Nearest to primarily: occupy, individualism, tentacles, innes, epping, aitken, kli, undaunted,
# Nearest to gold: wheelchair, leila, joysticks, cassino, patriots, colonizer, standpoints, godfather,
# Nearest to troops: kristianstad, lately, deficiencies, nabal, fewest, chants, attendees, acupuncturists,
# Nearest to units: firebrand, reusable, arising, corolla, wie, raven, interdiction, leiserson,
# Nearest to pre: tightened, testimonies, slur, sungorus, beached, lobo, permitted, solving,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4755 0.2036 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3881 0.2018 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3179 0.2017 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2873 0.2007 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2106 0.2021 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1451 0.2008 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1277 0.2018 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0639 0.2011 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0151 0.2014 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9902 0.2016 sec/batch
# Nearest to been: encouraged, melodic, palm, part, between, jewels, leges, component,
# Nearest to about: wwii, shave, octave, fellows, bottom, engage, assassinated, catarina,
# Nearest to at: consolidation, neo, lastly, cliath, delilah, frying, consults, wartime,
# Nearest to state: naturalized, breaks, spamalot, casino, motown, activities, slashes, ec,
# Nearest to but: tenth, displaced, antwerp, plancherel, shifted, error, aliens, precipitation,
# Nearest to used: emotive, tables, museum, portion, photons, pointed, walkways, roadster,
# Nearest to so: waveforms, regulating, occasion, jure, regressive, economic, minting, increasing,
# Nearest to a: alongside, construct, chromosomes, sports, recruited, supporters, creek, mircea,
# Nearest to articles: thrusts, hoover, mate, streamlined, cultures, addressable, proffered, demodulation,
# Nearest to channel: lane, representational, nameless, geological, flagella, lightly, determining, thalberg,
# Nearest to running: unlock, suggestive, replicant, discussing, evolving, functionals, extant, arguments,
# Nearest to primarily: occupy, tentacles, individualism, clock, innes, aitken, stranded, vicar,
# Nearest to gold: wheelchair, patriots, joysticks, cup, standpoints, sugars, leila, modifying,
# Nearest to troops: kristianstad, lately, fewest, chants, deficiencies, years, attendees, vesicle,
# Nearest to units: firebrand, reusable, following, arising, wie, alan, fm, raven,
# Nearest to pre: permitted, testimonies, tightened, beached, slur, elsewhere, mainframe, sungorus,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9176 0.2035 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8950 0.2013 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8620 0.2019 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8455 0.2024 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8156 0.2007 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8267 0.2012 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7797 0.2017 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7686 0.2016 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8028 0.2025 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7871 0.2020 sec/batch
# Nearest to been: encouraged, melodic, palm, heaviest, enforcement, ghost, unbiased, commenced,
# Nearest to about: wwii, shave, assassinated, octave, misdemeanors, gradual, kimmel, catarina,
# Nearest to at: consolidation, neo, lastly, frying, wartime, cliath, etymologies, consults,
# Nearest to state: naturalized, ec, spamalot, slashes, scripps, motown, bund, erection,
# Nearest to but: tenth, displaced, antwerp, plancherel, shifted, shock, fats, intrusion,
# Nearest to used: emotive, museum, tables, innovators, rallies, incidence, portion, photons,
# Nearest to so: waveforms, regulating, minting, occasion, jure, increasing, worcestershire, regressive,
# Nearest to a: alongside, chromosomes, supporters, construct, bookseller, recruited, activate, exemplifies,
# Nearest to articles: thrusts, hoover, mate, cultures, proffered, streamlined, addressable, destroyer,
# Nearest to channel: lane, representational, geological, flagella, nameless, lightly, thalberg, easters,
# Nearest to running: unlock, suggestive, replicant, discussing, confidant, extant, graphs, evolving,
# Nearest to primarily: occupy, individualism, tentacles, vicar, unsatisfactory, innes, clock, communicates,
# Nearest to gold: wheelchair, patriots, modifying, cup, sugars, remembered, joysticks, leila,
# Nearest to troops: kristianstad, lately, chants, deficiencies, fewest, years, marquee, eros,
# Nearest to units: reusable, firebrand, arising, raven, following, cinemas, fm, interdiction,
# Nearest to pre: permitted, tightened, testimonies, solving, slur, elsewhere, scalability, still,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7756 0.2029 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7550 0.2014 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7181 0.2021 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6944 0.2012 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7500 0.2019 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7009 0.2015 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7191 0.2011 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7395 0.2003 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7167 0.2008 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6701 0.2018 sec/batch
# Nearest to been: encouraged, melodic, palm, enforcement, meteorites, unbiased, heaviest, part,
# Nearest to about: wwii, misdemeanors, shave, assassinated, octave, kimmel, northerners, magnum,
# Nearest to at: consolidation, neo, frying, lastly, cliath, brine, etymologies, consults,
# Nearest to state: naturalized, spamalot, erection, scripps, slashes, anthropoid, ec, contests,
# Nearest to but: tenth, displaced, antwerp, intrusion, plancherel, shock, sassanian, shifted,
# Nearest to used: emotive, tables, amir, rallies, museum, incidence, innovators, osce,
# Nearest to so: regulating, waveforms, mousetrap, ripple, minting, increasing, waterproof, they,
# Nearest to a: chromosomes, alongside, supporters, bookseller, hickok, activate, exemplifies, pool,
# Nearest to articles: thrusts, proffered, streamlined, hoover, mate, addressable, demodulation, destroyer,
# Nearest to channel: lane, representational, lightly, geological, flagella, nameless, easters, lithuanian,
# Nearest to running: unlock, suggestive, replicant, discussing, confidant, graphs, kestrel, wilber,
# Nearest to primarily: tentacles, occupy, individualism, innes, epping, unsatisfactory, communicates, aitken,
# Nearest to gold: patriots, wheelchair, leila, joysticks, modifying, cup, sugars, cassino,
# Nearest to troops: lately, kristianstad, chants, immature, marquee, deficiencies, years, touted,
# Nearest to units: firebrand, reusable, interdiction, raven, arising, following, southside, cinemas,
# Nearest to pre: tightened, permitted, testimonies, solving, slur, beached, still, basing,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6765 0.2013 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6806 0.2005 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6371 0.2012 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6529 0.2022 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6217 0.2019 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6204 0.2014 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5960 0.1489 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5416 0.2012 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5126 0.2021 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5105 0.2013 sec/batch
# Nearest to been: encouraged, melodic, palm, meteorites, enforcement, part, between, unbiased,
# Nearest to about: misdemeanors, wwii, shave, octave, engage, northerners, bottom, kimmel,
# Nearest to at: frying, neo, cliath, delilah, consolidation, brine, lastly, consults,
# Nearest to state: naturalized, spamalot, erection, scripps, ec, soir, anthropoid, slashes,
# Nearest to but: tenth, displaced, antwerp, intrusion, sassanian, plancherel, shock, realises,
# Nearest to used: emotive, tables, amir, workstation, innovators, incidence, rallies, osce,
# Nearest to so: regulating, waveforms, ripple, waterproof, they, minting, mousetrap, regressive,
# Nearest to a: bookseller, pool, activate, hickok, chromosomes, alongside, exemplifies, supporters,
# Nearest to articles: thrusts, proffered, demodulation, narrowband, streamlined, mate, hoover, addressable,
# Nearest to channel: lane, representational, easters, geological, thalberg, flagella, lightly, nameless,
# Nearest to running: unlock, replicant, suggestive, discussing, wilber, confidant, kestrel, graphs,
# Nearest to primarily: occupy, tentacles, innes, epping, individualism, resurrect, communicates, unsatisfactory,
# Nearest to gold: patriots, wheelchair, leila, sugars, joysticks, cup, foreground, remembered,
# Nearest to troops: kristianstad, lately, battle, war, marquee, chants, immature, years,
# Nearest to units: firebrand, interdiction, reusable, arising, raven, microcomputers, following, cinemas,
# Nearest to pre: tightened, still, testimonies, permitted, beached, scalability, basing, solving,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4788 0.2022 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4884 0.2016 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4915 0.2014 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4932 0.2012 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4848 0.2009 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4783 0.2003 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4536 0.2008 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4004 0.2018 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4061 0.2006 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4288 0.2009 sec/batch
# Nearest to been: encouraged, meteorites, melodic, enforcement, palm, part, heaviest, niet,
# Nearest to about: misdemeanors, wwii, engage, waters, kimmel, octave, tzar, magnum,
# Nearest to at: frying, delilah, brine, consolidation, cliath, consults, lastly, neo,
# Nearest to state: naturalized, erection, spamalot, floated, scripps, soir, romania, national,
# Nearest to but: tenth, displaced, antwerp, intrusion, plancherel, rating, sassanian, clues,
# Nearest to used: emotive, tables, polysaccharides, amir, canines, particular, incidence, workstation,
# Nearest to so: regulating, waveforms, ripple, they, waterproof, decrying, minting, frey,
# Nearest to a: pool, activate, bookseller, chromosomes, exemplifies, barracuda, hickok, controllable,
# Nearest to articles: thrusts, proffered, demodulation, streamlined, narrowband, cultures, smyrna, addressable,
# Nearest to channel: lane, representational, easters, thalberg, nicaraguans, flagella, nair, inhibit,
# Nearest to running: unlock, replicant, suggestive, discussing, perot, curtailing, montoneros, minnesotans,
# Nearest to primarily: occupy, tentacles, epping, innes, utterances, communicates, reflected, resurrect,
# Nearest to gold: patriots, leila, wheelchair, sugars, joysticks, handing, cup, foreground,
# Nearest to troops: battle, war, kristianstad, marquee, lately, raids, chants, livia,
# Nearest to units: firebrand, interdiction, reusable, arising, raven, microcomputers, smf, following,
# Nearest to pre: tightened, basing, still, testimonies, permitted, beached, slur, scalability,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4594 0.2024 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4208 0.2013 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4415 0.2019 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3926 0.2010 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4264 0.2021 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4578 0.2018 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3891 0.2018 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3745 0.2011 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4061 0.2015 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3920 0.2021 sec/batch
# Nearest to been: encouraged, meteorites, enforcement, palm, melodic, part, niet, stub,
# Nearest to about: misdemeanors, waters, magnum, kimmel, engage, nsc, gradual, ogden,
# Nearest to at: frying, cliath, delilah, brine, lastly, consolidation, washing, consults,
# Nearest to state: erection, naturalized, floated, spamalot, anthropoid, contests, soir, scripps,
# Nearest to but: displaced, tenth, antwerp, plancherel, intrusion, sassanian, rating, dsl,
# Nearest to used: emotive, tables, polysaccharides, amir, innovators, workstation, incidence, particular,
# Nearest to so: regulating, waveforms, ripple, waterproof, decrying, they, minting, regressive,
# Nearest to a: activate, bookseller, exemplifies, pool, hickok, chromosomes, deion, neutral,
# Nearest to articles: thrusts, proffered, demodulation, narrowband, streamlined, gash, cultures, smyrna,
# Nearest to channel: lane, easters, representational, nair, thalberg, nicaraguans, phodopus, inhibit,
# Nearest to running: unlock, replicant, suggestive, curtailing, perot, montoneros, discussing, gradients,
# Nearest to primarily: occupy, tentacles, resurrect, innes, epping, utterances, communicates, reflected,
# Nearest to gold: patriots, leila, wheelchair, cup, handing, sugars, cassino, beech,
# Nearest to troops: war, battle, kristianstad, livia, raids, ussr, forces, peacekeeping,
# Nearest to units: interdiction, firebrand, reusable, microcomputers, arising, interact, smf, occurring,
# Nearest to pre: still, basing, tightened, beached, permitted, testimonies, experiences, elsewhere,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3688 0.2025 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4030 0.2016 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3448 0.2023 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3561 0.2008 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4073 0.2014 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3725 0.2019 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3895 0.2008 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3778 0.2022 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3189 0.2013 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3380 0.2011 sec/batch
# Nearest to been: encouraged, palm, commonwealth, enforcement, part, meteorites, volunteer, melodic,
# Nearest to about: misdemeanors, magnum, waters, engage, kimmel, wwii, ogden, nsc,
# Nearest to at: frying, brine, delilah, cliath, washing, neo, wartime, lastly,
# Nearest to state: naturalized, erection, constitution, scripps, national, floated, pleaded, soir,
# Nearest to but: displaced, tenth, antwerp, sassanian, rating, plancherel, dsl, intrusion,
# Nearest to used: emotive, polysaccharides, tables, particular, amir, oils, workstation, canines,
# Nearest to so: waveforms, regulating, ripple, waterproof, they, psychophysical, bugle, frey,
# Nearest to a: exemplifies, bookseller, hickok, deion, activate, resonate, alongside, recruited,
# Nearest to articles: proffered, thrusts, demodulation, narrowband, reyna, smyrna, gash, cultures,
# Nearest to channel: lane, easters, representational, nicaraguans, nair, inhibit, src, joysticks,
# Nearest to running: unlock, replicant, montoneros, perot, curtailing, suggestive, kestrel, minnesotans,
# Nearest to primarily: occupy, innes, resurrect, epping, utterances, tentacles, reflected, alluvial,
# Nearest to gold: patriots, leila, wheelchair, sugars, miners, cup, handing, beech,
# Nearest to troops: war, battle, raids, livia, invasion, forces, kristianstad, ussr,
# Nearest to units: interdiction, firebrand, reusable, smf, microcomputers, fm, raven, following,
# Nearest to pre: still, tightened, beached, basing, elsewhere, slur, experiences, prusias,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3584 0.2023 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2885 0.2025 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3885 0.2008 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3637 0.2010 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4066 0.2007 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2838 0.2016 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3167 0.1998 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3426 0.2012 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2430 0.2006 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2928 0.2025 sec/batch
# Nearest to been: encouraged, commonwealth, part, palm, niet, enforcement, rabbit, meteorites,
# Nearest to about: misdemeanors, magnum, waters, ogden, wwii, engage, catarina, kimmel,
# Nearest to at: frying, delilah, cliath, brine, neo, washing, wartime, fianc,
# Nearest to state: naturalized, constitution, erection, governors, legislature, scripps, judiciary, national,
# Nearest to but: displaced, tenth, antwerp, rating, plancherel, sassanian, titusville, intrusion,
# Nearest to used: emotive, polysaccharides, tables, oils, amir, particular, collimated, canines,
# Nearest to so: waveforms, ripple, regulating, physicalism, frey, sure, something, they,
# Nearest to a: exemplifies, activate, is, resonate, pool, hickok, bookseller, deion,
# Nearest to articles: proffered, thrusts, demodulation, narrowband, reyna, gash, cultures, smyrna,
# Nearest to channel: lane, easters, representational, nair, src, nicaraguans, subcover, inhibit,
# Nearest to running: unlock, replicant, montoneros, perot, curtailing, kestrel, savings, discussing,
# Nearest to primarily: epping, occupy, innes, resurrect, utterances, reflected, tentacles, alluvial,
# Nearest to gold: patriots, cup, wheelchair, miners, leila, sugars, fueled, handing,
# Nearest to troops: war, battle, forces, raids, ussr, kristianstad, peacekeeping, brigade,
# Nearest to units: interdiction, firebrand, reusable, mlp, smf, fumes, following, raven,
# Nearest to pre: beached, tightened, basing, still, elsewhere, experiences, testimonies, mainframe,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2901 0.2031 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2975 0.2017 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3193 0.0978 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2718 0.2013 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2782 0.2008 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2067 0.2006 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2079 0.2007 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2351 0.2009 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2126 0.2009 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1781 0.2001 sec/batch
# Nearest to been: encouraged, commonwealth, palm, enforcement, part, these, stub, niet,
# Nearest to about: misdemeanors, waters, magnum, ogden, engage, nsc, nv, pastures,
# Nearest to at: frying, delilah, brine, cliath, wartime, washing, numerator, argos,
# Nearest to state: naturalized, scripps, erection, constitution, soir, governors, legislature, behistun,
# Nearest to but: displaced, tenth, plancherel, antwerp, rating, sassanian, titusville, being,
# Nearest to used: emotive, polysaccharides, tables, amir, oils, synodic, workstation, mucous,
# Nearest to so: waveforms, regulating, ripple, physicalism, happiness, sure, decrying, frey,
# Nearest to a: is, exemplifies, resonate, activate, tasmania, pool, rapidity, bookseller,
# Nearest to articles: proffered, thrusts, demodulation, narrowband, gash, reyna, cultures, lustrum,
# Nearest to channel: lane, easters, nair, src, nicaraguans, representational, subcover, joysticks,
# Nearest to running: unlock, replicant, montoneros, curtailing, perot, kestrel, minnesotans, savings,
# Nearest to primarily: epping, occupy, tentacles, innes, resurrect, utterances, reflected, alluvial,
# Nearest to gold: patriots, cup, wheelchair, miners, foreground, fueled, sugars, leila,
# Nearest to troops: war, battle, forces, brigade, kristianstad, raids, ussr, peacekeeping,
# Nearest to units: interdiction, firebrand, reusable, smf, mlp, raven, commissars, microcomputers,
# Nearest to pre: beached, tightened, basing, mesopotamia, still, mitanni, phenomenological, slur,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2467 0.2028 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2229 0.2012 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2124 0.2003 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1474 0.2002 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2022 0.2008 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1793 0.2009 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1840 0.2008 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1842 0.2020 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1897 0.2008 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1850 0.2000 sec/batch
# Nearest to been: encouraged, commonwealth, rabbit, enforcement, niet, melodic, these, outwit,
# Nearest to about: misdemeanors, waters, magnum, ogden, gaia, pastures, nv, nsc,
# Nearest to at: frying, delilah, cliath, numerator, brine, argos, lastly, washing,
# Nearest to state: naturalized, undergraduate, erection, national, constitution, governors, scripps, emblems,
# Nearest to but: displaced, tenth, plancherel, titusville, being, sassanian, intrusion, antwerp,
# Nearest to used: polysaccharides, emotive, activates, tables, flavoring, collimated, workstation, oils,
# Nearest to so: waveforms, regulating, ripple, physicalism, waterproof, sure, painstaking, they,
# Nearest to a: is, activate, infty, currying, specify, exemplifies, resonate, geometric,
# Nearest to articles: proffered, thrusts, demodulation, bibliographic, cultures, gash, narrowband, elish,
# Nearest to channel: lane, easters, src, nair, broadcasting, subcover, joysticks, nicaraguans,
# Nearest to running: unlock, replicant, montoneros, ddd, workstations, perot, curtailing, candlestick,
# Nearest to primarily: tentacles, resurrect, occupy, reflected, innes, epping, utterances, phthalocyanine,
# Nearest to gold: patriots, miners, sugars, fueled, leila, wheelchair, hollandic, extracted,
# Nearest to troops: war, battle, brigade, kristianstad, forces, ussr, raids, peacekeeping,
# Nearest to units: interdiction, reusable, firebrand, smf, mlp, microcomputers, raven, commissars,
# Nearest to pre: basing, tightened, beached, mesopotamia, mitanni, phenomenological, slur, mainframe,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1534 0.2004 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2369 0.2013 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2137 0.2012 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1572 0.2004 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2031 0.2005 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1562 0.2021 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2156 0.2013 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1611 0.2014 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1412 0.2022 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1908 0.2006 sec/batch
# Nearest to been: commonwealth, encouraged, rabbit, outwit, part, melodic, monopolies, niet,
# Nearest to about: misdemeanors, magnum, waters, ogden, gaia, pastures, engage, gradual,
# Nearest to at: frying, delilah, cliath, numerator, brine, moderne, windsurfing, argos,
# Nearest to state: naturalized, erection, undergraduate, constitution, governors, national, legislature, pleaded,
# Nearest to but: displaced, tenth, plancherel, rating, antwerp, being, sassanian, diminished,
# Nearest to used: emotive, polysaccharides, het, amir, tables, particular, walkways, flavoring,
# Nearest to so: waveforms, ripple, physicalism, regulating, sure, painstaking, they, waterproof,
# Nearest to a: is, infty, exemplifies, currying, bookseller, specify, geometric, wegener,
# Nearest to articles: proffered, thrusts, bibliographic, demodulation, reyna, gash, lustrum, narrowband,
# Nearest to channel: lane, easters, nair, src, broadcasting, subcover, mckernan, thalberg,
# Nearest to running: unlock, replicant, montoneros, perot, ddd, curtailing, discussing, enver,
# Nearest to primarily: tentacles, resurrect, innes, occupy, utterances, reflected, epping, communicates,
# Nearest to gold: patriots, sugars, miners, fueled, extracted, foreground, hollandic, leila,
# Nearest to troops: war, battle, kristianstad, brigade, forces, peacekeeping, commanders, iraqi,
# Nearest to units: interdiction, reusable, firebrand, mlp, smf, microcomputers, following, commissars,
# Nearest to pre: tightened, beached, mitanni, basing, mesopotamia, phenomenological, mainframe, mestizo,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2295 0.2017 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1892 0.2008 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2021 0.2011 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1967 0.2026 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1364 0.2019 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1329 0.2011 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1783 0.2013 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1129 0.2026 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2102 0.2011 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2224 0.2017 sec/batch
# Nearest to been: encouraged, commonwealth, niet, part, enforcement, malaysia, rabbit, oecs,
# Nearest to about: misdemeanors, magnum, waters, ogden, gaia, engage, pastures, kimmel,
# Nearest to at: delilah, frying, cliath, fife, argos, neo, brine, moderne,
# Nearest to state: naturalized, legislature, erection, national, constitution, governors, undergraduate, crets,
# Nearest to but: displaced, tenth, plancherel, antwerp, sassanian, narbonensis, intrusion, titusville,
# Nearest to used: emotive, polysaccharides, het, tables, activates, walkways, nonterminal, amir,
# Nearest to so: waveforms, sure, ripple, physicalism, painstaking, waterproof, regulating, they,
# Nearest to a: is, serbian, alongside, hickok, exemplifies, petition, recruited, granting,
# Nearest to articles: proffered, thrusts, reyna, bibliographic, elish, lustrum, demodulation, gash,
# Nearest to channel: lane, easters, nair, src, subcover, joysticks, broadcasting, nicaraguans,
# Nearest to running: unlock, replicant, perot, montoneros, enver, ddd, printings, candlestick,
# Nearest to primarily: tentacles, resurrect, innes, reflected, epping, utterances, occupy, alluvial,
# Nearest to gold: patriots, miners, sugars, fueled, extracted, cup, hollandic, foreground,
# Nearest to troops: war, battle, brigade, forces, kristianstad, iraqi, peacekeeping, operation,
# Nearest to units: interdiction, firebrand, mlp, reusable, smf, commissars, following, microcomputers,
# Nearest to pre: tightened, mitanni, beached, mesopotamia, mestizo, phenomenological, mainframe, iceland,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2155 0.2018 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1307 0.2011 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1642 0.2002 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1672 0.2006 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0442 0.2008 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1517 0.2016 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1704 0.2014 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1148 0.2014 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1680 0.0445 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1168 0.2023 sec/batch
# Nearest to been: encouraged, commonwealth, malaysia, part, enforcement, niet, archiver, melodic,
# Nearest to about: misdemeanors, waters, magnum, ogden, gaia, pastures, engage, corrects,
# Nearest to at: frying, delilah, cliath, numerator, brine, moderne, windsurfing, neo,
# Nearest to state: naturalized, crets, states, governors, national, behistun, legislature, austin,
# Nearest to but: displaced, plancherel, tenth, narbonensis, titusville, feelin, antwerp, being,
# Nearest to used: emotive, polysaccharides, nonterminal, walkways, activates, collimated, tables, synodic,
# Nearest to so: waveforms, sure, physicalism, ripple, waterproof, advantageous, painstaking, they,
# Nearest to a: is, serbian, infty, alongside, resonate, exemplifies, abrupt, substitutable,
# Nearest to articles: proffered, thrusts, elish, reyna, portal, bibliographic, lustrum, narrowband,
# Nearest to channel: lane, easters, src, nair, broadcasting, mckernan, subcover, television,
# Nearest to running: unlock, replicant, montoneros, enver, ddd, perot, printings, workstations,
# Nearest to primarily: tentacles, innes, resurrect, utterances, epping, phthalocyanine, reflected, alluvial,
# Nearest to gold: patriots, miners, extracted, sugars, fueled, cup, canes, hollandic,
# Nearest to troops: war, battle, brigade, kristianstad, forces, peacekeeping, iraqi, vicksburg,
# Nearest to units: interdiction, firebrand, mlp, reusable, commissars, following, microcomputers, smf,
# Nearest to pre: mainframe, mitanni, tightened, beached, mestizo, mesopotamia, phenomenological, eschewed,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0935 0.2027 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0687 0.2012 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1324 0.2008 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0492 0.2008 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0765 0.2014 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0857 0.2008 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0917 0.2014 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0831 0.2007 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1274 0.2011 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0373 0.2007 sec/batch
# Nearest to been: encouraged, commonwealth, enforcement, part, malaysia, these, niet, skagerrak,
# Nearest to about: waters, misdemeanors, pastures, ogden, magnum, gaia, nv, catarina,
# Nearest to at: frying, delilah, numerator, cliath, windsurfing, minutes, argos, chasing,
# Nearest to state: naturalized, crets, undergraduate, states, legislature, austin, national, erection,
# Nearest to but: displaced, plancherel, tenth, overtook, being, rating, for, antwerp,
# Nearest to used: polysaccharides, emotive, flavoring, walkways, nonterminal, rallies, activates, workstation,
# Nearest to so: waveforms, sure, physicalism, ripple, waterproof, painstaking, advantageous, regulating,
# Nearest to a: is, resonate, infty, alongside, substitutable, friulian, exemplifies, currying,
# Nearest to articles: proffered, elish, thrusts, bibliographic, portal, reyna, lustrum, cultures,
# Nearest to channel: lane, easters, nair, broadcasting, mckernan, src, subcover, television,
# Nearest to running: unlock, printings, montoneros, ddd, enver, replicant, brake, workstations,
# Nearest to primarily: tentacles, resurrect, innes, phthalocyanine, reflected, glaciology, utterances, heroin,
# Nearest to gold: patriots, miners, extracted, cup, fueled, sugars, canes, wheelchair,
# Nearest to troops: war, battle, brigade, forces, kristianstad, armored, vicksburg, commanders,
# Nearest to units: interdiction, firebrand, reusable, mlp, commissars, reconnaissance, smf, microcomputers,
# Nearest to pre: mitanni, tightened, mestizo, mesopotamia, beached, phenomenological, basing, mainframe,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0380 0.2025 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0178 0.2002 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0107 0.2002 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0499 0.2015 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0436 0.2009 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0544 0.1998 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0809 0.2008 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0868 0.2009 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0434 0.2009 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0538 0.2006 sec/batch
# Nearest to been: encouraged, commonwealth, niet, part, enforcement, melodic, malaysia, these,
# Nearest to about: waters, pastures, misdemeanors, gaia, ogden, magnum, nv, rinzai,
# Nearest to at: delilah, frying, numerator, cliath, windsurfing, moderne, minutes, argos,
# Nearest to state: naturalized, undergraduate, crets, erection, national, massachusetts, scripps, austin,
# Nearest to but: displaced, plancherel, dsl, nor, for, being, tenth, spatial,
# Nearest to used: emotive, polysaccharides, nonterminal, tables, congeners, roadster, het, collimated,
# Nearest to so: waveforms, sure, physicalism, waterproof, mousetrap, painstaking, ripple, they,
# Nearest to a: is, infty, substitutable, an, currying, geometric, tensor, resonate,
# Nearest to articles: proffered, elish, bibliographic, portal, reyna, website, thrusts, superfluid,
# Nearest to channel: lane, nair, easters, broadcasting, television, src, mckernan, subcover,
# Nearest to running: unlock, montoneros, replicant, printings, workstations, enver, brake, ddd,
# Nearest to primarily: tentacles, innes, resurrect, phthalocyanine, undaunted, reflected, heroin, upgrade,
# Nearest to gold: patriots, miners, extracted, fueled, cup, canes, sugars, foreground,
# Nearest to troops: war, brigade, kristianstad, battle, forces, commanders, iraqi, armored,
# Nearest to units: interdiction, mlp, reusable, firebrand, commissars, reconnaissance, smf, unit,
# Nearest to pre: mitanni, tightened, phenomenological, mestizo, mesopotamia, mainframe, eschewed, beached,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0551 0.2025 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0653 0.2008 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0830 0.2014 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0436 0.2003 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0702 0.2014 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0499 0.2006 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0648 0.2004 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0723 0.2015 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0877 0.2010 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0714 0.2011 sec/batch
# Nearest to been: commonwealth, malaysia, encouraged, aroostook, xiongnu, jogaila, skagerrak, part,
# Nearest to about: waters, misdemeanors, gaia, pastures, magnum, ogden, tzar, rinzai,
# Nearest to at: frying, delilah, cliath, in, numerator, minutes, windsurfing, moderne,
# Nearest to state: naturalized, crets, legislature, erection, undergraduate, alde, scripps, austin,
# Nearest to but: displaced, narbonensis, antwerp, for, tenth, plancherel, dsl, nor,
# Nearest to used: emotive, nonterminal, flavoring, rallies, congeners, walkways, polysaccharides, het,
# Nearest to so: sure, waveforms, physicalism, repent, advantageous, painstaking, something, mousetrap,
# Nearest to a: is, friulian, seminoles, substitutable, heresiologists, salsa, jinx, alongside,
# Nearest to articles: proffered, elish, portal, bibliographic, reyna, superfluid, thrusts, gov,
# Nearest to channel: lane, nair, broadcasting, easters, television, src, mckernan, subcover,
# Nearest to running: unlock, printings, fingal, montoneros, enver, workstations, perot, replicant,
# Nearest to primarily: tentacles, innes, resurrect, reflected, phthalocyanine, nationalization, embraces, heroin,
# Nearest to gold: miners, patriots, extracted, sugars, fueled, canes, cup, availabilitymales,
# Nearest to troops: war, brigade, kristianstad, forces, commanders, battle, iraqi, waged,
# Nearest to units: mlp, interdiction, firebrand, commissars, reusable, smf, reconnaissance, si,
# Nearest to pre: mitanni, mestizo, phenomenological, mesopotamia, tightened, beached, mainframe, iceland,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0772 0.2018 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9929 0.2014 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0763 0.2000 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0570 0.2019 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0896 0.2009 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1135 0.2007 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1535 0.2013 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0482 0.2012 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0223 0.1999 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0574 0.2011 sec/batch
# Nearest to been: encouraged, commonwealth, aroostook, enforcement, niet, part, skagerrak, tibi,
# Nearest to about: misdemeanors, waters, pastures, external, gaia, magnum, malcom, ogden,
# Nearest to at: delilah, frying, in, cliath, moderne, numerator, minutes, beside,
# Nearest to state: crets, naturalized, legislature, disorganised, erection, austin, undergraduate, alde,
# Nearest to but: displaced, for, plancherel, narbonensis, tenth, antwerp, diminished, overtook,
# Nearest to used: emotive, nonterminal, flavoring, walkways, congeners, collimated, polysaccharides, activates,
# Nearest to so: sure, waveforms, physicalism, repent, mousetrap, advantageous, happiest, something,
# Nearest to a: is, substitutable, resonate, salsa, exemplifies, infty, seminoles, an,
# Nearest to articles: proffered, elish, portal, reyna, thrusts, bibliographic, website, superfluid,
# Nearest to channel: lane, nair, easters, broadcasting, subcover, mckernan, src, television,
# Nearest to running: unlock, fingal, enver, printings, workstations, torvalds, montoneros, replicant,
# Nearest to primarily: tentacles, innes, resurrect, nationalization, reflected, phthalocyanine, alluvial, embraces,
# Nearest to gold: patriots, miners, extracted, cup, availabilitymales, canes, iron, fueled,
# Nearest to troops: war, iraqi, kristianstad, forces, brigade, commanders, battle, peacekeeping,
# Nearest to units: mlp, interdiction, commissars, firebrand, unit, reusable, si, waw,
# Nearest to pre: mainframe, mitanni, mestizo, phenomenological, tightened, eschewed, beached, mesopotamia,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9768 0.2021 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0247 0.2018 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0341 0.2005 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0678 0.2010 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0655 0.2006 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0318 0.1938 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0351 0.2011 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9991 0.2014 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0242 0.2015 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9901 0.2020 sec/batch
# Nearest to been: encouraged, aroostook, commonwealth, enforcement, part, diatomic, tibi, architects,
# Nearest to about: waters, misdemeanors, malcom, nv, pastures, gaia, magnum, catarina,
# Nearest to at: in, frying, delilah, cliath, moderne, numerator, beside, time,
# Nearest to state: crets, naturalized, austin, behistun, disorganised, alde, scripps, undergraduate,
# Nearest to but: displaced, narbonensis, ascend, feelin, overtook, nor, tenth, for,
# Nearest to used: emotive, nonterminal, rallies, walkways, congeners, flavoring, collimated, roadster,
# Nearest to so: sure, waveforms, mousetrap, advantageous, repent, physicalism, happiest, repentant,
# Nearest to a: is, resonate, seminoles, salsa, recruited, an, infty, libra,
# Nearest to articles: proffered, elish, portal, bibliographic, reyna, lustrum, thrusts, website,
# Nearest to channel: lane, nair, broadcasting, television, easters, src, mckernan, subcover,
# Nearest to running: unlock, workstations, printings, fingal, enver, torvalds, ddd, deride,
# Nearest to primarily: tentacles, innes, phthalocyanine, resurrect, heroin, embraces, upgrade, reflected,
# Nearest to gold: miners, patriots, cup, extracted, canes, iron, availabilitymales, fueled,
# Nearest to troops: war, kristianstad, battle, brigade, iraqi, curtiss, forces, junkers,
# Nearest to units: mlp, interdiction, commissars, unit, si, reusable, firebrand, reconnaissance,
# Nearest to pre: mitanni, phenomenological, mainframe, mestizo, tightened, beached, eschewed, mesopotamia,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0011 0.2020 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9441 0.2007 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0343 0.2013 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0147 0.2009 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0124 0.2007 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9892 0.2010 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9583 0.2011 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9499 0.2011 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9296 0.2017 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9869 0.2017 sec/batch
# Nearest to been: encouraged, diatomic, enforcement, commonwealth, aroostook, archiver, galba, tibi,
# Nearest to about: waters, pastures, external, nv, eukaryote, misdemeanors, gaia, malcom,
# Nearest to at: in, delilah, frying, beside, numerator, farrow, moderne, minutes,
# Nearest to state: crets, california, naturalized, austin, undergraduate, alde, massachusetts, scripps,
# Nearest to but: displaced, tenth, nor, overtook, diminished, plancherel, ascend, narbonensis,
# Nearest to used: emotive, nonterminal, flavoring, congeners, walkways, collimated, rallies, polysaccharides,
# Nearest to so: waveforms, sure, advantageous, mousetrap, physicalism, minting, replacing, waterproof,
# Nearest to a: is, resonate, an, infty, seminoles, taking, specify, substitutable,
# Nearest to articles: proffered, elish, portal, bibliographic, website, reyna, thrusts, lustrum,
# Nearest to channel: lane, television, broadcasting, nair, src, mckernan, easters, subcover,
# Nearest to running: unlock, fingal, printings, workstations, enver, replicant, interstate, ddd,
# Nearest to primarily: tentacles, innes, phthalocyanine, resurrect, upgrade, heroin, trna, li,
# Nearest to gold: patriots, miners, cup, extracted, availabilitymales, canes, fueled, cosmos,
# Nearest to troops: war, kristianstad, iraqi, junkers, battle, brigade, commanders, curtiss,
# Nearest to units: mlp, commissars, unit, interdiction, reconnaissance, reusable, firebrand, waw,
# Nearest to pre: mitanni, mestizo, beached, mesopotamia, phenomenological, eschewed, stems, tightened,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0029 0.2024 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9758 0.2009 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9525 0.2014 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0170 0.2011 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0256 0.2015 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9634 0.2004 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9730 0.2009 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9661 0.2014 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9934 0.2014 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0030 0.2005 sec/batch
# Nearest to been: diatomic, encouraged, aroostook, tibi, commonwealth, niet, architects, xiongnu,
# Nearest to about: waters, pastures, malcom, catarina, external, nv, gaia, misdemeanors,
# Nearest to at: in, delilah, beside, minutes, numerator, farrow, time, moderne,
# Nearest to state: crets, naturalized, california, alde, undergraduate, austin, underpinnings, body,
# Nearest to but: displaced, plancherel, nor, for, dsl, being, tenth, feelin,
# Nearest to used: emotive, nonterminal, congeners, rallies, het, walkways, collimated, flavoring,
# Nearest to so: sure, waveforms, repent, they, physicalism, repentant, advantageous, something,
# Nearest to a: is, an, taking, specify, seminoles, infty, as, resonate,
# Nearest to articles: proffered, elish, bibliographic, reyna, website, lustrum, portal, thrusts,
# Nearest to channel: lane, television, broadcasting, nair, src, mckernan, easters, subcover,
# Nearest to running: unlock, printings, workstations, fingal, torvalds, enver, replicant, deride,
# Nearest to primarily: tentacles, innes, resurrect, heroin, embraces, upgrade, phthalocyanine, undaunted,
# Nearest to gold: patriots, miners, cup, availabilitymales, els, canes, cosmos, extracted,
# Nearest to troops: war, kristianstad, battle, brigade, commanders, iraqi, junkers, vicksburg,
# Nearest to units: mlp, unit, interdiction, si, commissars, reusable, waw, firebrand,
# Nearest to pre: mitanni, phenomenological, mainframe, eschewed, mestizo, stems, beached, mesopotamia,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9999 0.2031 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9920 0.2011 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9825 0.2005 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0186 0.2005 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0280 0.2005 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0206 0.2011 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9635 0.2007 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9672 0.2009 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9682 0.2005 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0027 0.2020 sec/batch
# Nearest to been: diatomic, encouraged, aroostook, enforcement, tibi, commonwealth, revert, archiver,
# Nearest to about: external, waters, pastures, misdemeanors, malcom, eukaryote, catarina, gaia,
# Nearest to at: in, delilah, moderne, honorary, time, minutes, beside, numerator,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8287 0.2009 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8819 0.2011 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9006 0.2004 sec/batch
# Nearest to been: have, many, however, now, revert, record, these, though,
# Nearest to about: eukaryote, malcom, birger, catarina, saville, there, external, shepard,
# Nearest to at: in, four, three, beside, farrow, time, the, graduation,
# Nearest to state: crets, states, austin, underpinnings, california, banyan, alde, obey,
# Nearest to but: be, ascend, nor, him, to, had, thulsa, for,
# Nearest to used: nonterminal, use, as, antoninianus, rallies, commonly, often, flavoring,
# Nearest to so: sure, waveforms, replacing, johan, something, gdynia, be, hydroxide,
# Nearest to a: is, the, an, by, in, of, to, as,
# Nearest to articles: mediawiki, superfluid, website, encyclop, bibliographic, tempo, links, page,
# Nearest to channel: lane, viewers, broadcasting, mckernan, television, broadcaster, nair, overlord,
# Nearest to running: enver, fingal, run, torvalds, replicant, interstate, unlock, printings,
# Nearest to primarily: tentacles, firmicutes, upgrade, resurrect, turmeric, cyrix, macs, swamps,
# Nearest to gold: silver, cup, patriots, availabilitymales, minted, precious, reiterates, longfellow,
# Nearest to troops: vicksburg, kristianstad, dougal, battle, desiderius, caballus, army, ncos,
# Nearest to units: unit, mlp, si, commissars, roxanne, fuerzas, per, firebrand,
# Nearest to pre: archaeology, iala, maya, voids, mitanni, beached, columbian, nonterminals,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8208 0.2023 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8794 0.2017 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8478 0.2013 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8618 0.2015 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8689 0.2016 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8653 0.2007 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8752 0.2009 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8441 0.2011 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8346 0.2011 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8711 0.2013 sec/batch
# Nearest to been: many, have, now, revert, however, had, the, recently,
# Nearest to about: catarina, eukaryote, birger, malcom, shepard, external, there, measures,
# Nearest to at: in, four, three, beside, the, time, farrow, eight,
# Nearest to state: crets, states, austin, obey, the, alde, underpinnings, banyan,
# Nearest to but: had, ascend, to, nor, be, by, overtook, for,
# Nearest to used: nonterminal, use, often, antoninianus, as, rallies, emotive, commonly,
# Nearest to so: sure, something, i, replacing, waveforms, you, radiohead, johan,
# Nearest to a: is, the, an, by, of, in, to, and,
# Nearest to articles: mediawiki, superfluid, encyclop, tempo, page, zeppelin, bibliographic, pageant,
# Nearest to channel: broadcasting, lane, mckernan, viewers, nair, broadcaster, television, tv,
# Nearest to running: fingal, enver, unlock, replicant, torvalds, interstate, printings, run,
# Nearest to primarily: upgrade, turmeric, resurrect, firmicutes, tentacles, cyrix, macs, mottled,
# Nearest to gold: silver, minted, cup, patriots, availabilitymales, precious, reiterates, cosmos,
# Nearest to troops: kristianstad, vicksburg, artillery, battle, dougal, army, caballus, ncos,
# Nearest to units: unit, mlp, si, commissars, fuerzas, roxanne, firebrand, per,
# Nearest to pre: maya, iala, columbian, archaeology, voids, beached, mitanni, guarani,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8791 0.2025 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8367 0.2009 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8203 0.2009 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8385 0.2000 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9087 0.2015 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8212 0.2022 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9739 0.2024 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8964 0.2007 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9089 0.2010 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8104 0.2014 sec/batch
# Nearest to been: have, many, had, recently, now, that, the, however,
# Nearest to about: catarina, birger, external, sunburst, eukaryote, malcom, shepard, pastures,
# Nearest to at: in, four, beside, three, farrow, the, seven, eight,
# Nearest to state: crets, states, austin, the, obey, underpinnings, banyan, capitalists,
# Nearest to but: ascend, overtook, nor, fela, be, had, though, for,
# Nearest to used: nonterminal, use, often, as, commonly, antoninianus, flavoring, rallies,
# Nearest to so: sure, something, i, radiohead, replacing, gdynia, johan, you,
# Nearest to a: the, is, of, by, an, in, to, and,
# Nearest to articles: superfluid, mediawiki, encyclop, zeppelin, tempo, page, pageant, bibliographic,
# Nearest to channel: lane, viewers, mckernan, broadcasting, broadcaster, nair, src, mieszko,
# Nearest to running: fingal, unlock, torvalds, enver, run, replicant, interstate, brake,
# Nearest to primarily: turmeric, upgrade, resurrect, cyrix, tentacles, firmicutes, main, crucial,
# Nearest to gold: silver, patriots, cup, minted, precious, availabilitymales, reiterates, cosmos,
# Nearest to troops: kristianstad, artillery, vicksburg, army, peacekeeping, caballus, dougal, ncos,
# Nearest to units: unit, mlp, si, commissars, fuerzas, roxanne, per, weight,
# Nearest to pre: iala, maya, columbian, archaeology, voids, beached, mitanni, buggy,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8323 0.2016 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8558 0.2013 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8109 0.2012 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8501 0.2012 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8424 0.2012 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8497 0.2016 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8533 0.1337 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8319 0.2022 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8401 0.2020 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8603 0.2014 sec/batch
# Nearest to been: have, many, that, had, the, however, now, revert,
# Nearest to about: catarina, to, birger, there, shepard, raining, eukaryote, malcom,
# Nearest to at: in, the, four, beside, of, three, farrow, time,
# Nearest to state: states, crets, austin, underpinnings, obey, the, alde, banyan,
# Nearest to but: had, to, ascend, nor, the, of, be, narbonensis,
# Nearest to used: nonterminal, use, commonly, often, as, synthetic, flavoring, rallies,
# Nearest to so: sure, replacing, something, hydroxide, i, johan, be, radiohead,
# Nearest to a: the, by, of, is, and, an, in, to,
# Nearest to articles: mediawiki, superfluid, zeppelin, pageant, tempo, encyclop, website, bibliographic,
# Nearest to channel: lane, viewers, mckernan, broadcasting, broadcaster, nair, src, tv,
# Nearest to running: fingal, run, unlock, torvalds, enver, interstate, replicant, cornerbacks,
# Nearest to primarily: turmeric, upgrade, resurrect, firmicutes, cyrix, tentacles, mottled, macs,
# Nearest to gold: silver, cup, precious, patriots, minted, availabilitymales, cosmos, reiterates,
# Nearest to troops: battle, kristianstad, vicksburg, artillery, army, desiderius, ncos, dougal,
# Nearest to units: unit, mlp, si, commissars, roxanne, weight, dallwitz, fuerzas,
# Nearest to pre: maya, iala, archaeology, columbian, voids, buggy, beached, mitanni,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8099 0.2029 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8312 0.2005 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8359 0.2018 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8288 0.2000 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8445 0.2014 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8382 0.2008 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8805 0.2011 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7313 0.2006 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8152 0.1995 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8004 0.1999 sec/batch
# Nearest to been: have, many, that, however, had, has, the, these,
# Nearest to about: catarina, measures, there, eukaryote, to, raining, external, malcom,
# Nearest to at: in, four, three, the, beside, seven, six, farrow,
# Nearest to state: crets, states, austin, obey, underpinnings, the, banyan, alde,
# Nearest to but: to, the, had, be, ascend, nor, for, and,
# Nearest to used: use, nonterminal, as, often, commonly, synthetic, flavoring, describe,
# Nearest to so: sure, be, i, that, it, gdynia, replacing, you,
# Nearest to a: is, the, an, by, in, to, of, and,
# Nearest to articles: mediawiki, website, encyclop, page, bibliographic, pageant, superfluid, zeppelin,
# Nearest to channel: viewers, broadcasting, lane, mckernan, broadcaster, tv, television, nair,
# Nearest to running: unlock, fingal, run, interstate, enver, torvalds, brake, rival,
# Nearest to primarily: turmeric, firmicutes, upgrade, resurrect, mottled, tentacles, cyrix, macs,
# Nearest to gold: silver, cup, precious, patriots, minted, availabilitymales, lindsay, reiterates,
# Nearest to troops: army, artillery, battle, vicksburg, kristianstad, ncos, caballus, desiderius,
# Nearest to units: unit, mlp, si, commissars, weight, fuerzas, roxanne, per,
# Nearest to pre: columbian, maya, archaeology, iala, voids, mitanni, socratic, beached,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7764 0.2010 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8223 0.2009 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8755 0.2009 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8126 0.2005 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8180 0.2003 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9098 0.2010 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8076 0.2012 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7989 0.2012 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8436 0.2012 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8197 0.2019 sec/batch
# Nearest to been: have, many, however, has, some, now, that, since,
# Nearest to about: there, to, catarina, birger, measures, raining, malcom, eukaryote,
# Nearest to at: in, four, beside, farrow, three, time, the, eight,
# Nearest to state: crets, states, underpinnings, obey, alde, austin, isotropy, excellency,
# Nearest to but: to, the, be, had, is, nor, for, of,
# Nearest to used: nonterminal, use, as, often, commonly, antoninianus, emotive, modern,
# Nearest to so: sure, be, radiohead, i, waveforms, replacing, it, something,
# Nearest to a: is, the, an, by, in, of, to, as,
# Nearest to articles: mediawiki, encyclop, website, bibliographic, zeppelin, superfluid, pageant, dia,
# Nearest to channel: viewers, lane, broadcasting, mckernan, broadcaster, tv, nair, xena,
# Nearest to running: run, torvalds, interstate, unlock, enver, cornerbacks, fingal, rival,
# Nearest to primarily: turmeric, resurrect, firmicutes, upgrade, tentacles, macs, cyrix, crucial,
# Nearest to gold: silver, precious, cup, patriots, minted, lindsay, availabilitymales, reiterates,
# Nearest to troops: artillery, kristianstad, multimedia, peacekeeping, army, vicksburg, ncos, caballus,
# Nearest to units: unit, mlp, si, commissars, roxanne, is, fuerzas, weight,
# Nearest to pre: columbian, maya, iala, voids, archaeology, nonterminals, socratic, mitanni,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8509 0.2028 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8572 0.2008 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8202 0.2016 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8329 0.2007 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8444 0.2014 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8540 0.2016 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8207 0.2005 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8375 0.2011 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8097 0.2008 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8260 0.2007 sec/batch
# Nearest to been: have, however, many, that, the, had, now, some,
# Nearest to about: to, there, measures, catarina, birger, malcom, eukaryote, conversation,
# Nearest to at: in, four, three, the, six, eight, one, seven,
# Nearest to state: crets, states, the, always, austin, excellency, alde, underpinnings,
# Nearest to but: the, be, to, for, as, and, is, it,
# Nearest to used: nonterminal, use, as, often, describe, commonly, antoninianus, to,
# Nearest to so: sure, be, that, i, radiohead, it, something, still,
# Nearest to a: is, the, by, in, an, of, to, and,
# Nearest to articles: mediawiki, website, zeppelin, kuro, encyclop, page, superfluid, bibliographic,
# Nearest to channel: viewers, broadcasting, mckernan, broadcaster, tv, lane, crt, nair,
# Nearest to running: run, unlock, torvalds, enver, fingal, interstate, brake, cornerbacks,
# Nearest to primarily: turmeric, firmicutes, resurrect, tentacles, upgrade, mottled, angolan, cyrix,
# Nearest to gold: silver, precious, cup, patriots, minted, availabilitymales, lindsay, reiterates,
# Nearest to troops: artillery, army, battle, invasion, vicksburg, kristianstad, caballus, peacekeeping,
# Nearest to units: unit, mlp, si, commissars, roxanne, fuerzas, per, dallwitz,
# Nearest to pre: columbian, maya, archaeology, iala, voids, aztec, beached, mitanni,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8560 0.2026 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8331 0.2031 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9174 0.2018 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8786 0.2014 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9154 0.2013 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8213 0.2013 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7770 0.2013 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8237 0.2008 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7444 0.2008 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8173 0.2014 sec/batch
# Nearest to been: have, many, however, some, the, has, had, that,
# Nearest to about: there, catarina, birger, sportswriter, raining, remakes, malcom, to,
# Nearest to at: in, four, the, three, and, eight, beside, graduation,
# Nearest to state: crets, states, austin, underpinnings, alde, incorporation, banyan, legislature,
# Nearest to but: the, be, to, as, for, though, is, fela,
# Nearest to used: use, often, as, nonterminal, commonly, antoninianus, combined, describe,
# Nearest to so: sure, that, be, radiohead, i, something, you, still,
# Nearest to a: is, the, by, in, an, of, to, and,
# Nearest to articles: zeppelin, website, mediawiki, eurasian, page, kuro, superfluid, bibliographic,
# Nearest to channel: viewers, broadcasting, mckernan, nair, lane, xena, broadcaster, mieszko,
# Nearest to running: run, torvalds, unlock, fingal, rival, enver, cornerbacks, minnesotans,
# Nearest to primarily: turmeric, firmicutes, resurrect, tentacles, upgrade, mottled, swamps, angolan,
# Nearest to gold: silver, cup, precious, minted, lindsay, patriots, availabilitymales, reiterates,
# Nearest to troops: artillery, kristianstad, caballus, desiderius, vicksburg, army, invasion, ncos,
# Nearest to units: unit, si, mlp, commissars, roxanne, fuerzas, nist, dallwitz,
# Nearest to pre: columbian, maya, iala, voids, archaeology, aztec, beached, buggy,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8501 0.2031 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8132 0.2008 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
